# %%
# !git clone https://github.com/apt2736/PKM_RF.git
# Out:
# Cloning into 'PKM_RF'...
# remote: Enumerating objects: 1659, done.
# remote: Counting objects: 100% (252/252), done.
# remote: Compressing objects: 100% (174/174), done.
# remote: Total 1659 (delta 169), reused 159 (delta 78), pack-reused 1407 (from 1)
# Receiving objects: 100% (1659/1659), 105.47 MiB | 29.73 MiB/s, done.
# Resolving deltas: 100% (1196/1196), done.
# Updating files: 100% (118/118), done.

# %%
# %cd PKM_RF

# !git fetch --all
# !git reset --hard origin/master
# Out:
# [Errno 2] No such file or directory: 'PKM_RF'
# /kaggle/working/PKM_RF
# Fetching origin
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 1), reused 6 (delta 1), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 3.23 MiB | 10.75 MiB/s, done.
# From https://github.com/apt2736/PKM_RF
#    0fa11dc..023c66c  master     -> origin/master
# HEAD is now at 023c66c feat: notebook to convert dataset to csv

# %%
# %run data_convert_to_csv.ipynb
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# Loading raw RData dataset from: datasets/5v_cleandf.RData
# Raw Dataset Loaded: 560486 Rows x 972 Columns
# Exporting Raw Dataset to datasets/5v_raw.csv ...

# %%
# %run setup.ipynb
# Out:
# ===> Checking R installation...
# R is already installed:
# Rscript (R) version 4.6.0 (2026-04-24)
# ===> Ensuring Python rpy2, cmake, lightgbm, xgboost, optuna, and imbalanced-learn (SMOTE) are installed...
# ===> Installing R prebuilt binary packages via APT...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# r-cran-data.table is already the newest version (1.18.4-1.ca2204.1).
# r-cran-data.table set to manually installed.
# r-cran-dplyr is already the newest version (1.2.1-1.ca2204.1).
# r-cran-dplyr set to manually installed.
# r-cran-jsonlite is already the newest version (2.0.0-1.ca2204.1).
# r-cran-jsonlite set to manually installed.
# r-cran-ggplot2 is already the newest version (4.0.3-1.ca2204.1).
# r-cran-ggplot2 set to manually installed.
# The following additional packages will be installed:
#   r-cran-clock r-cran-diagram r-cran-foreach r-cran-future r-cran-future.apply
# ...

# %%
# %run models/train_oof_logistic_regression_stacking.ipynb
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# ...
#   INITIAL DATASET LOADED: 560486 Total Rows, 972 Total Columns
# ...
# Initial ESI Target Distribution (including NAs):
#
#      1      2      3      4      5   <NA>
#   5271 163534 236229 125003  27992   2457
# ------------------------------------------------------------------------
# Missing Values Filter: Dropped 396044 rows with >= 1 NA feature (Retained 164442 Complete Cases, 29.34%)
# Cleaned ESI Distribution (100% complete cases):
#
#     1     2     3     4     5
#   208 48106 71067 37864  7197
# ------------------------------------------------------------------------
# 3-Way Partition Complete:
#   Train Set      = 115109 rows (70.00%)
#   Validation Set = 32888 rows (20.00%)
#   Holdout Test   = 16445 rows (10.00%)
# ...
# Training Base Sub-Models on Train Set (98%) with Validation Set Early Stopping...
# ...

# %%
# %run models/transpile_soft_pipeline_to_c.ipynb
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# Extracted Init Scores: L1=0.000000, L2=0.000000, L3A=0.000000, L3B=0.000000
# ...

# %%
# !zip -r density_plots.zip /kaggle/working/PKM_RF/plots/density
# Out:
# updating: kaggle/working/PKM_RF/plots/density/ (stored 0%)
# updating: kaggle/working/PKM_RF/plots/density/density_triage_vital_sbp.png (deflated 9%)
# updating: kaggle/working/PKM_RF/plots/density/density_sbp_min.png (deflated 8%)
# updating: kaggle/working/PKM_RF/plots/density/density_triage_vital_hr.png (deflated 10%)
# updating: kaggle/working/PKM_RF/plots/density/density_pulse_min.png (deflated 9%)
# updating: kaggle/working/PKM_RF/plots/density/density_gender.png (deflated 22%)
# updating: kaggle/working/PKM_RF/plots/density/density_age.png (deflated 6%)
# updating: kaggle/working/PKM_RF/plots/density/density_cc_breathingdifficulty.png (deflated 25%)
# updating: kaggle/working/PKM_RF/plots/density/density_resp_min.png (deflated 13%)
# updating: kaggle/working/PKM_RF/plots/density/density_spo2_max.png (deflated 17%)
# updating: kaggle/working/PKM_RF/plots/density/density_triage_vital_rr.png (deflated 15%)
# ...
